# %%
import pandas as pd

# %%
df = pd.read_csv("clean_data/high_school_filtered.csv")
df
# Out:
#                 RCDTS    Type               District  School Type  \
# 0     010011720220003  School          Quincy SD 172  HIGH SCHOOL
# 1     010691170220014  School    Jacksonville SD 117  HIGH SCHOOL
# 2     040041000260002  School     Belvidere CUSD 100  HIGH SCHOOL
# 3     040042000260003  School   North Boone CUSD 200  HIGH SCHOOL
# 4     041011220220002  School          Harlem UD 122  HIGH SCHOOL
# ..                ...     ...                    ...          ...
# 200  0560992100160004  School   Lincoln Way CHSD 210  HIGH SCHOOL
# 201  056099200U260001  School      Beecher CUSD 200U  HIGH SCHOOL
# 202  056099201U260001  School  Crete Monee CUSD 201U  HIGH SCHOOL
# 203  056099365U260007  School  Valley View CUSD 365U  HIGH SCHOOL
# 204  056099365U260008  School  Valley View CUSD 365U  HIGH SCHOOL
#
#                City     County District Type District Size  \
# 0            Quincy      Adams          UNIT         LARGE
# ...
