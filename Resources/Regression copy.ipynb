# %%
import pandas as pd

# %%
regression_df = pd.read_csv("clean_data/ELA and Math clean.csv")
regression_df

#added avg score 

regression_df['ELA_Math_Avg'] = (regression_df['ELA'] + regression_df['Math']) / 2 
regression_df
# Out:
#                 RCDTS County  Dist #  District Name/ School Name         City  \
# 0     010010010260000   Adams      10              Payson CUSD 1       Payson
# 1     010010010260001   Adams      10        Seymour High School       Payson
# 2     010010020260000   Adams      20             Liberty CUSD 2      Liberty
# 3     010010020260001   Adams      20        Liberty High School      Liberty
# 4     010010030260000   Adams      30             Central CUSD 3   Camp Point
# ...               ...     ...     ...                        ...          ...
# 1192  56099255U260000    Will    255U      Reed Custer CUSD 255U    Braidwood
# 1193  56099255U260001    Will    255U    Reed-Custer High School    Braidwood
# 1194  56099365U260000    Will    365U      Valley View CUSD 365U   Romeoville
# 1195  56099365U260007    Will    365U    Bolingbrook High School  Bolingbrook
# 1196  56099365U260008    Will    365U     Romeoville High School   Romeoville
#
#         ELA   Math  ELA_Math_Avg
# 0     524.3  489.1        506.70
# 1     524.3  489.1        506.70
# 2     500.9  485.4        493.15
# 3     500.9  485.4        493.15
# 4     490.6  488.3        489.45
# ...     ...    ...           ...
# 1192  479.1  483.8        481.45
# 1193  480.3  484.9        482.60
# 1194  490.3  489.1        489.70
# 1195  490.0  490.8        490.40
# 1196  493.2  488.3        490.75
#
# [1197 rows x 8 columns]

# %%
general_df = pd.read_csv("general.csv")
general_df
# Out:
# /Users/johnmorrissey/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                 RCDTS       Type                       School Name  \
# 0      10010010260000   District                               NaN
# 1      10010010260001     School               Seymour High School
# 2      10010010262002     School         Seymour Elementary School
# 3      10010020260000   District                               NaN
# 4      10010020260001     School               Liberty High School
# ...               ...        ...                               ...
# 4749  56099365U262014     School         Pioneer Elementary School
# 4750  56099365U262015     School    Kenneth L Hermansen Elementary
# 4751  56099365U262016     School                  Skoff Elementary
# 4752  56099365U263002     School  Valley View Early Childhood Cntr
# 4753              NaN  Statewide                               NaN
#
#                    District         City County District Type District Size  \
# 0             Payson CUSD 1       Payson  Adams          UNIT        MEDIUM
# 1             Payson CUSD 1       Payson  Adams          UNIT        MEDIUM
# 2             Payson CUSD 1       Payson  Adams          UNIT        MEDIUM
# 3            Liberty CUSD 2      Liberty  Adams          UNIT        MEDIUM
# 4            Liberty CUSD 2      Liberty  Adams          UNIT        MEDIUM
# ...                     ...          ...    ...           ...           ...
# 4749  Valley View CUSD 365U  Bolingbrook   Will          UNIT         LARGE
# 4750  Valley View CUSD 365U   Romeoville   Will          UNIT         LARGE
# 4751  Valley View CUSD 365U   Romeoville   Will          UNIT         LARGE
# 4752  Valley View CUSD 365U   Romeoville   Will          UNIT         LARGE
# 4753                    NaN          NaN    NaN           NaN           NaN
#
#       School Type     Grades Served  ...  \
# 0             NaN               NaN  ...
# 1     HIGH SCHOOL    7 8 9 10 11 12  ...
# 2      ELEMENTARY  PK K 1 2 3 4 5 6  ...
# 3             NaN               NaN  ...
# 4     HIGH SCHOOL    7 8 9 10 11 12  ...
# ...           ...               ...  ...
# 4749   ELEMENTARY       K 1 2 3 4 5  ...
# 4750   ELEMENTARY       K 1 2 3 4 5  ...
# 4751   ELEMENTARY       K 1 2 3 4 5  ...
# 4752         PreK                PK  ...
# 4753          NaN               NaN  ...
#
#      Five Essential Survey Involved Families Level  \
# 0                                              NaN
# 1                                              3.0
# 2                                              2.0
# 3                                              NaN
# 4                                              0.0
# ...                                            ...
# 4749                                           3.0
# 4750                                           2.0
# 4751                                           3.0
# 4752                                           4.0
# 4753                                           NaN
#
#       Five Essential Survey Supportive Environment  \
# 0                                              NaN
# 1                                             49.0
# 2                                             56.0
# 3                                              NaN
# 4                                              0.0
# ...                                            ...
# 4749                                           0.0
# 4750                                           0.0
# 4751                                           0.0
# 4752                                           0.0
# 4753                                           NaN
#
#       Five Essential Survey Supportive Environment Level  \
# 0                                                   NaN
# 1                                                   3.0
# 2                                                   3.0
# 3                                                   NaN
# 4                                                   0.0
# ...                                                 ...
# 4749                                                0.0
# 4750                                                0.0
# 4751                                                0.0
# 4752                                                0.0
# 4753                                                NaN
#
#       Five Essential Survey Ambitious Instruction  \
# 0                                             NaN
# 1                                            45.0
# 2                                            40.0
# 3                                             NaN
# 4                                             0.0
# ...                                           ...
# 4749                                          0.0
# 4750                                          0.0
# 4751                                          0.0
# 4752                                          0.0
# 4753                                          NaN
#
#       Five Essential Survey Ambitious Instruction.1  \
# 0                                               NaN
# 1                                               3.0
# 2                                               3.0
# 3                                               NaN
# 4                                               0.0
# ...                                             ...
# 4749                                            0.0
# 4750                                            0.0
# 4751                                            0.0
# 4752                                            0.0
# 4753                                            NaN
#
#       Five Essential Survey Student Response Rate %  \
# 0                                               NaN
# 1                                              91.4
# 2                                              97.5
# 3                                               NaN
# 4                                               0.0
# ...                                             ...
# 4749                                            0.0
# 4750                                            0.0
# 4751                                            0.0
# 4752                                            0.0
# 4753                                            NaN
#
#       Five Essential Survey Teacher Response Rate %  \
# 0                                               NaN
# 1                                              75.0
# 2                                              99.9
# 3                                               NaN
# 4                                              47.1
# ...                                             ...
# 4749                                           99.9
# 4750                                           99.9
# 4751                                           99.9
# 4752                                           99.9
# 4753                                            NaN
#
#       Five Essential Survey Schools with over 50% Response Rate %  \
# 0                                                 100.0
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   0.0
# 4                                                   NaN
# ...                                                 ...
# 4749                                                NaN
# 4750                                                NaN
# 4751                                                NaN
# 4752                                                NaN
# 4753                                               89.0
#
#       Five Essential Survey Student Response Rate Median  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4749                                                NaN
# 4750                                                NaN
# 4751                                                NaN
# 4752                                                NaN
# 4753                                               78.7
#
#       Five Essential Survey Teacher Response Rate Median
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4749                                                NaN
# 4750                                                NaN
# 4751                                                NaN
# 4752                                                NaN
# 4753                                               82.6
#
# [4754 rows x 390 columns]

# %%
gen_df = general_df.filter(['RCDTS', 'Student Enrollment - Low Income %', 'Avg Class Size – All Grades', 'Avg Teaching Exp',
                           'Bachelor Degree', 'Masters Degree', 'Teacher Retention Rate', 'Admin Avg Salary'], axis = 1)
gen_df = gen_df.dropna()
gen_df.rename(columns = {'Avg Class Size – All Grades':'ClassSize'}, inplace = True)
gen_df.rename(columns = {'Student Enrollment - Low Income %':'LowIncome'}, inplace = True)
gen_df
# Out:
#                 RCDTS  LowIncome  ClassSize  Avg Teaching Exp  \
# 0      10010010260000       48.8       17.0              11.5
# 3      10010020260000       24.9       20.0              13.5
# 6      10010030260000       46.7       19.0              12.5
# 11     10010040260000       20.2       18.0              14.1
# 15     10011720220000       60.7       18.0              12.0
# ...               ...        ...        ...               ...
# 4708  56099201U260000       68.5       21.0              11.7
# 4717  56099207U260000       20.6       18.0              13.9
# 4723  56099209U260000       42.0       20.0              11.9
# 4728  56099255U260000       38.7       21.0              13.5
# 4732  56099365U260000       62.4       21.0              11.8
#
#       Bachelor Degree  Masters Degree  Teacher Retention Rate  \
# 0                56.3            43.8                    92.9
# 3                41.9            58.1                    91.5
# 6                42.9            57.1                    81.3
# 11               61.3            38.7                    89.7
# 15               56.9            42.6                    73.6
# ...               ...             ...                     ...
# 4708             39.3            60.7                    82.3
# 4717             55.2            43.8                    80.6
# 4723             47.9            49.9                    88.6
# 4728             31.3            68.7                    83.5
# 4732             26.8            73.0                    86.2
#
#       Admin Avg Salary
# 0             72141.72
# 3             83605.24
# 6             75068.50
# 11            83692.00
# 15            82764.57
# ...                ...
# 4708         105027.16
# 4717          91263.46
# 4723          99781.38
# 4728         107871.60
# 4732          92895.94
#
# [851 rows x 8 columns]

# %%
df = pd.merge(regression_df, gen_df, on = "RCDTS", how = "left")
df = df.dropna()
df
# Out:
#                 RCDTS      County  Dist #   \
# 989   500821870260000  Saint Clair    1870
# 991   500821880220000  Saint Clair    1880
# 993   500821890220000  Saint Clair    1890
# 995   500821960260000  Saint Clair    1960
# 997   500822010170000  Saint Clair    2010
# 1000  500822030170000  Saint Clair    2030
# 1002  510652000260000       Menard    2000
# 1004  510652020260000       Menard    2020
# 1006  510652130260000       Menard    2130
# 1008  510840010260000     Sangamon      10
# 1010  510840050260000     Sangamon      50
# 1012  510840080260000     Sangamon      80
# 1014  510840100260000     Sangamon     100
# 1016  510840110260000     Sangamon     110
# 1018  510840140260000     Sangamon     140
# 1020  510840150260000     Sangamon     150
# 1022  510840160260000     Sangamon     160
# 1024  510841860250000     Sangamon    1860
# 1029  530601260260000        Mason    1260
# 1031  530601890260000        Mason    1890
# 1033  530601910260000        Mason    1910
# 1035  530903030160000     Tazewell    3030
# 1037  530903080160000     Tazewell    3080
# 1010       20.1       23.0              13.4             54.9            44.7
# 1012       10.9       23.0              15.9             61.9            38.1
# 1014       35.2       23.0              16.1             55.3            42.3
# 1016       27.1       15.0              14.1             58.3            41.7
# 1018       53.1       19.0              12.4             63.1            36.9
# 1020        7.9       21.0              14.4             54.3            44.6
# 1022       33.4       18.0              10.7             48.0            52.0
# 1024       67.5       20.0              14.6             47.2            52.6
# 1029       55.6       18.0              16.2             33.4            66.6
# 1031       39.8       10.0              11.6             66.3            33.7
# 1033       55.0       16.0              14.4             56.8            43.2
# 1035       42.9       19.0              10.9             55.7            41.4
# 1037       21.7       18.0              16.1             32.9            65.9
# 1039       51.0       14.0              13.4             32.5            67.5
# 1041       20.5       20.0              13.5             62.9            37.1
# 1043       13.1       20.0              14.3             33.0            65.4
# 1045       37.9       15.0              10.7             63.0            37.0
# 1047       14.9       23.0              13.8             40.3            59.7
# 1049       47.0       18.0              14.6             46.8            53.2
# 1051       37.7       18.0              16.3             46.6            53.4
# 1053       50.7       14.0              16.9             64.3            32.1
# 1055       23.7       17.0              16.3             50.1            49.9
# 1057       17.3       23.0              16.4             33.3            65.1
# 1059       22.0       20.0              15.7             36.3            62.7
# 1061       59.9       19.0              12.3             70.3            29.7
# 1063       60.9       19.0              13.0             67.6            30.9
# 1065       48.4       15.0               8.1             73.7            26.3
# 1066       66.2       17.0              10.3             69.7            30.3
# 1068       41.5       18.0              10.4             74.7            25.3
# 1070       68.7       19.0              12.8             51.5            48.5
# 1072       42.5        9.0              11.1             50.0            50.0
# 1074       42.7       19.0              15.3             58.9            41.1
# 1078       27.2       21.0              12.0             36.9            62.9
# 1083       60.2       23.0              13.2             18.3            79.9
# 1086       17.8       22.0              13.9             20.3            79.7
# 1088        6.8       20.0              14.5              9.4            90.6
# 1099       37.3       16.0              14.1             62.0            36.9
# 1101       59.6       15.0              13.8             79.1            20.9
# 1103       76.3       17.0              16.8             55.8            40.7
# 1105       66.3       14.0              13.8             73.5            26.5
# 1107       36.1       17.0              12.2             61.9            38.1
# 1176       54.9       14.0              13.9             52.6            44.9
# 1182       13.8       24.0              15.4             52.9            47.1
# 1184       20.7       18.0              13.2             36.4            63.6
# 1186       68.5       21.0              11.7             39.3            60.7
# 1188       20.6       18.0              13.9             55.2            43.8
# 1190       42.0       20.0              11.9             47.9            49.9
# 1192       38.7       21.0              13.5             31.3            68.7
# 1194       62.4       21.0              11.8             26.8            73.0
#
#       Teacher Retention Rate  Admin Avg Salary
# 989                     80.6          99262.57
# 991                     83.3         113291.51
# 993                     75.8          97685.79
# 995                     91.3          96239.27
# 997                     92.8         108767.39
# 1000                    94.7         111454.35
# 1002                    83.3          86215.77
# 1004                    90.1          98200.41
# 1006                    89.2         100527.02
# 1008                    71.7          93040.58
# 1010                    87.6          88093.00
# 1012                    91.5         106814.27
# 1014                    86.9          95048.03
# 1016                    86.0          93622.00
# 1018                    81.9          83681.25
# 1020                    87.9         104260.52
# 1022                    86.5          97595.50
# 1024                    89.9          99802.81
# 1029                    86.2          91481.77
# 1031                    84.8          78016.72
# 1033                    86.6          84981.21
# 1035                    85.0          78343.07
# 1037                    95.0          95030.68
# 1039                    91.8          89211.50
# 1041                    89.6          86119.35
# 1043                    91.8          92978.83
# 1045                    87.3          89413.33
# 1047                    90.2          97428.88
# 1049                    60.9          90843.96
# 1051                    78.4          98400.73
# 1053                    87.4          84744.22
# 1055                    93.6         119677.67
# 1057                    92.9          91870.20
# 1059                    90.6          87885.64
# 1061                    81.6          87848.24
# 1063                    77.1          74215.00
# 1065                    72.3          97350.00
# 1066                    70.2          75572.27
# 1068                    80.1          74466.52
# 1070                    79.5          91382.86
# 1072                    83.3          91297.33
# 1074                    89.6          74706.32
# 1078                    88.2          96101.47
# 1083                    92.0         114960.85
# 1086                    93.1         125175.08
# 1088                    88.4         121663.65
# 1099                    90.5          68181.98
# 1101                    79.5          96472.66
# 1103                    87.5          89250.32
# 1105                    91.9          77262.00
# 1107                    88.9         100250.00
# 1176                    82.3          99982.87
# 1182                    89.4          89930.73
# 1184                    89.0          93750.38
# 1186                    82.3         105027.16
# 1188                    80.6          91263.46
# 1190                    88.6          99781.38
# 1192                    83.5         107871.60
# 1194                    86.2          92895.94

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
plt.scatter(df.ClassSize, df.Math)
plt.xlabel('Class Size')
plt.ylabel('Math')
plt.show()

X = df.ClassSize.values.reshape(-1, 1)
y = df.Math
model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)
print(y_pred.shape)

plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

print("Coefficient ", model.coef_)
print("Intercept ", model.intercept_)
# Out:
# (59,)
# Coefficient  [5.51731224]
# Intercept  382.5306868759773

# %%
plt.scatter(df.ClassSize, df.ELA)
plt.xlabel('Class Size')
plt.ylabel('ELA')
plt.show()

X = df.ClassSize.values.reshape(-1, 1)
y = df.ELA
model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)
print(y_pred.shape)

plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

print("Coefficient ", model.coef_)
print("Intercept ", model.intercept_)
# Out:
# (59,)
# Coefficient  [5.04189823]
# Intercept  403.13818116203527

# %%
plt.scatter(df.LowIncome, df.Math)
plt.xlabel('Income')
plt.ylabel('Math')
print(plt.show())

X = df.LowIncome.values.reshape(-1, 1)
y = df.Math
model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)
print(y_pred.shape)

plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
print(plt.show())

print("Coefficient ", model.coef_)
print("Intercept ", model.intercept_)
# Out:
# None
# (59,)
# None
# Coefficient  [-1.55735277]
# Intercept  548.2398182060892

# %%
plt.scatter(df.LowIncome, df.ELA)
plt.xlabel('Income')
plt.ylabel('ELA')
print(plt.show())

X = df.LowIncome.values.reshape(-1, 1)
y = df.ELA
model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)
print(y_pred.shape)

plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
print(plt.show())

print("Coefficient ", model.coef_)
print("Intercept ", model.intercept_)
# Out:
# None
# (59,)
# None
# Coefficient  [-1.42214696]
# Intercept  554.5257448476511
